# %% [markdown]
# # Analise de Resultados - Global Solution 2026
#
# Este notebook executa os modulos principais, carrega resultados de desempenho e apoia a escala de decisao.

# %%
import sys
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.append(str(ROOT))
from src.performance_monitor import main as run_performance
from src.visualizations import main as make_figures
run_performance()
make_figures()

# %% [markdown]
# ## Interpretacao
#
# A Forca Bruta valida a otimalidade em instancias pequenas, mas se torna inviavel em N alto. O Prim mantem custo baixo e, para MST, encontra solucao otima em grafos conectados com pesos nao negativos.
